-- %%
CREATE OR REPLACE TEMPORARY VIEW vDimNeighbourhood AS
SELECT 
     Id AS NeighbourhoodKey, 
     Neighbourhood, 
     CASE 
          WHEN lower(Neighbourhood) = 'kensington and chelsea' OR lower(Neighbourhood) = 'city of london' OR lower (Neighbourhood) = 'camden' THEN 'Fancy ✨' 
          ELSE 'Standard' 
     END AS NeighbourhoodCategory
FROM Silver_Airbnb.Neighbourhood
-- Out:
-- StatementMeta(, 431eb647-0463-4cac-b899-07ed35f4b2b6, 4, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
MERGE INTO Gold_Airbnb.DimNeighbourhood USING vDimNeighbourhood ON Gold_Airbnb.DimNeighbourhood.NeighbourhoodKey = vDimNeighbourhood.NeighbourhoodKey
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *;
-- Out:
-- StatementMeta(, 431eb647-0463-4cac-b899-07ed35f4b2b6, 5, Finished, Available)
-- <Spark SQL result set with 1 rows and 4 fields>
