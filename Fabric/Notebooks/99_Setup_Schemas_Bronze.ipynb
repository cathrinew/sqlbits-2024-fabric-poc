-- %% [markdown]
-- # ⚙️ Create or alter existing Bronze tables 🥉

-- %%
CREATE TABLE IF NOT EXISTS Bronze_Airbnb.Date ( 
    DateKey int,
    Date timestamp, 
    Day int,
    DayInWeekNum int,
    DayName string,
    WeekNum int,
    MonthNum int,
    MonthName string,
    MonthAndYearName string,
    YearMonth string,
    Quarter string,
    YearQuarter string,
    Year int,
    DaysBetween string,
    MonthsBetween string,
    TodayFlag string,
    ThisWeekFlag string,
    ThisMonthFlag string,
    LastMonthFlag string,
    ThisQuarterFlag string,
    ThisYearFlag string
) USING DELTA
-- Out:
-- StatementMeta(, 18614598-f42c-4d4b-bebc-097be37e9cea, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>
