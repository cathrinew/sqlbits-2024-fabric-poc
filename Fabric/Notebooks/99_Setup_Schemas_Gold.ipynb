-- %% [markdown]
-- # ⚙️ Create or alter existing Gold tables 🥇

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.DimDate (
    DateKey int,
    Date timestamp, 
    Day int,
    DayInWeekNum int,
    DayName string,
    WeekNum int,
    MonthNum int,
    MonthName string,
    MonthAndYearName string,
    YearMonth string,
    Quarter string,
    YearQuarter string,
    Year int,
    DaysBetween string,
    MonthsBetween string,
    TodayFlag string,
    ThisWeekFlag string,
    ThisMonthFlag string,
    LastMonthFlag string,
    ThisQuarterFlag string,
    ThisYearFlag string
) USING DELTA
-- Out:
-- StatementMeta(, 5905d7bf-b776-4636-86bd-1e7c54f09f19, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.DimHost (
    HostKey int,
    HostName string,
    HostType string,
    HostSince date,
    HostResponseRate double,
    HostAcceptanceRate double,
    HostURL string
) USING DELTA
-- Out:
-- StatementMeta(, 5905d7bf-b776-4636-86bd-1e7c54f09f19, 3, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.DimListing (
    ListingKey int,
    ListingName string,
    ListingURL string,
    ListingLatitude double,
    ListingLongitude double,
    IsListingInstantBookable boolean
) USING DELTA
-- Out:
-- StatementMeta(, 5905d7bf-b776-4636-86bd-1e7c54f09f19, 4, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.DimNeighbourhood (
    NeighbourhoodKey int, 
    Neighbourhood string,
    NeighbourhoodCategory string
) USING DELTA
-- Out:
-- StatementMeta(, 5905d7bf-b776-4636-86bd-1e7c54f09f19, 5, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.DimPropertyType (
    PropertyTypeKey int, 
    PropertyType string, 
    PropertyTypeCategory string
) USING DELTA
-- Out:
-- StatementMeta(, 5905d7bf-b776-4636-86bd-1e7c54f09f19, 6, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.DimRoomType (
    RoomTypeKey int, 
    RoomType string, 
    RoomTypeCategory string
) USING DELTA
-- Out:
-- StatementMeta(, ca580cb5-bfdf-4c26-b7bd-bb913fba3e12, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_Airbnb.FactListings (
    DateKey int, 
    HostKey int,
    ListingKey int, 
    NeighbourhoodKey int,
    PropertyTypeKey int, 
    RoomTypeKey int, 
    Price double, 
    MinimumNights int, 
    NumberOfReviews int, 
    LastReview timestamp, 
    ReviewsPerMonth int, 
    CalculatedHostListingsCount int, 
    Availability365 int
) USING DELTA
-- Out:
-- StatementMeta(, 9ee673b0-d4a5-4126-a006-1db71cd757fc, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>
