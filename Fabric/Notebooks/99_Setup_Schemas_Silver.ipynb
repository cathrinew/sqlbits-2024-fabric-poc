-- %% [markdown]
-- # ⚙️ Create or alter existing Silver tables 🥈

-- %%
CREATE TABLE IF NOT EXISTS Silver_Airbnb.Date (
    DateKey int,
    Date timestamp,
    Day int,
    DayInWeekNum int,
    DayName string,
    WeekNum int,
    MonthNum int,
    MonthName string,
    MonthAndYearName string,
    YearMonth string,
    Quarter string,
    YearQuarter string,
    Year int,
    DaysBetween string,
    MonthsBetween string,
    TodayFlag string,
    ThisWeekFlag string,
    ThisMonthFlag string,
    LastMonthFlag string,
    ThisQuarterFlag string,
    ThisYearFlag string
) USING DELTA
-- Out:
-- StatementMeta(, , , Waiting, )
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_Airbnb.Host (
    Id int,
    Name string,
    HostType string,
    HostSince date,
    Neighbourhood string,
    City string,
    Country string,
    ResponseTime string,
    ResponseRate double,
    AcceptanceRate double,
    HostURL string,
    HostPictureURL string,
    HostPictureThumbnailURL string,
    About string
) USING DELTA
-- Out:
-- StatementMeta(, , , Waiting, )
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_Airbnb.Listings (
    Id bigint,
    Name string,
    HostId int,
    HostSince date,
    License string,
    Neighbourhood string,
    NeighbourhoodId int,
    Latitude double,
    Longitude double,
    RoomType string,
    RoomTypeId int,
    PropertyType string,
    PropertyTypeId int,
    URL string,
    InstantBookable boolean,
    Price double,
    MinimumNights int,
    LastReview date,
    NumberOfReviews int,
    NumberOfReviewsLtm int,
    ReviewsPerMonth decimal,
    CalculatedHostListingsCount int,
    Availability365 int
) USING DELTA
-- Out:
-- StatementMeta(, bd2c4c45-98c2-4bf5-96c0-fe27599a62fd, 4, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_Airbnb.Neighbourhood (
    Id int,
    Neighbourhood string
) USING DELTA
-- Out:
-- StatementMeta(, , , Waiting, )
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_Airbnb.PropertyType (
    Id int,
    PropertyType string
) USING DELTA
-- Out:
-- StatementMeta(, , , Waiting, )
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_Airbnb.Reviews (
    Id bigint,
    ListingId bigint,
    ReviewDate date,
    Review string
) USING DELTA
-- Out:
-- StatementMeta(, bd2c4c45-98c2-4bf5-96c0-fe27599a62fd, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_Airbnb.RoomType (
    Id int,
    RoomType string
) USING DELTA
-- Out:
-- StatementMeta(, , , Waiting, )
-- <Spark SQL result set with 0 rows and 0 fields>
