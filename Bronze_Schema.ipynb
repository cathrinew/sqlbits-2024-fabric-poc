-- %% [markdown]
-- # This notebook is used for creating or altering existing tables in the Silver layer

-- %%
CREATE TABLE Bronze_AirBnB_Lakehouse.DimDate ( 
        DateKey string,
        Date timestamp, 
        Day int,
        DayInWeekNum int,
        DayName string,
        WeekNum int,
        MonthNum int,
        MonthName string,
        MonthAndYearName string,
        YearMonth string,
        Quarter string,
        YearQuarter string,
        Year int,
        DaysBetween string,
        MonthsBetween string,
        TodayFlag string,
        ThisWeekFlag string,
        ThisMonthFlag string,
        LastMonthFlag string,
        ThisQuarterFlag string,
        ThisYearFlag string
    ) USING DELTA
-- Out:
-- StatementMeta(, 237a16ba-743a-4e1a-9f54-b6acfa7c3308, 3, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>
