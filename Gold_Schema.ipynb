-- %% [markdown]
-- # This notebook is used for creating or altering existing tables in the Silver layer

-- %%
CREATE TABLE Gold_AirBnB_Lakehouse.DimDate ( 
        DateKey int,
        Date timestamp, 
        Day int,
        DayInWeekNum int,
        DayName string,
        WeekNum int,
        MonthNum int,
        MonthName string,
        MonthAndYearName string,
        YearMonth string,
        Quarter string,
        YearQuarter string,
        Year int,
        DaysBetween string,
        MonthsBetween string,
        TodayFlag string,
        ThisWeekFlag string,
        ThisMonthFlag string,
        LastMonthFlag string,
        ThisQuarterFlag string,
        ThisYearFlag string
    ) USING DELTA
-- Out:
-- StatementMeta(, 84545f06-8cc8-49ca-a81b-2c0c4b7ee64d, 4, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_AirBnB_Lakehouse.dimroomtypes (
Id INT, 
RoomType String, 
RoomTypeCategory String
) USING DELTA;
-- Out:
-- StatementMeta(, 84545f06-8cc8-49ca-a81b-2c0c4b7ee64d, 5, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_AirBnB_Lakehouse.dimneighbourhood (
Id INT, 
Neighbourhood String,
NeighbourhoodCategory String
) USING DELTA;
-- Out:
-- StatementMeta(, 68fd3218-78ff-4ad8-9471-3946e6a28422, 3, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_AirBnB_Lakehouse.factlistings (
Listingid INT, 
Datekey int, 
HostId INT, 
NeighbourhoodId INT, 
RoomTypeId INT, 
price Double, 
minimumNights INT, 
NumberOfReviews INT, 
LastReview timestamp, 
ReviewsPerMonth INT, 
CalculatedHostListingsCount INT, 
availability365 INT
) USING DELTA;
-- Out:
-- StatementMeta(, 68fd3218-78ff-4ad8-9471-3946e6a28422, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Gold_AirBnB_Lakehouse.dimlistings (
Listingid INT, 
Name STRING, 
Latitude double, 
Longitude double, 
Licens string
) USING DELTA;
-- Out:
-- StatementMeta(, 27481d0e-439d-42dc-9d96-2b31ff2c5e0b, 4, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>
