-- %% [markdown]
-- # This notebook is used for creating or altering existing tables in the Silver layer

-- %%
CREATE TABLE Silver_AirBnB_Lakehouse.DimDate ( 
        DateKey int,
        Date timestamp, 
        Day int,
        DayInWeekNum int,
        DayName string,
        WeekNum int,
        MonthNum int,
        MonthName string,
        MonthAndYearName string,
        YearMonth string,
        Quarter string,
        YearQuarter string,
        Year int,
        DaysBetween string,
        MonthsBetween string,
        TodayFlag string,
        ThisWeekFlag string,
        ThisMonthFlag string,
        LastMonthFlag string,
        ThisQuarterFlag string,
        ThisYearFlag string
    ) USING DELTA
-- Out:
-- StatementMeta(, 2bb11551-72ad-4d60-a886-819692bf30d8, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_AirBnB_Lakehouse.dimroomtypes (
Id INT, 
RoomType String
) USING DELTA;
-- Out:
-- StatementMeta(, 425487e1-aad7-44e3-bb5a-2bd69ad6872c, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_AirBnB_Lakehouse.dimneighbourhood (
Id INT, 
Neighbourhood String
) USING DELTA;
-- Out:
-- StatementMeta(, ac2f4dc0-d8b0-4a88-8770-a7559403a3cc, 2, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE OR REPLACE TABLE Silver_AirBnB_Lakehouse.dimlistings (
ListingId BIGINT, 
name string,
hostid int, 
NeighbourhoodId Int, 
latitude double, 
longitude double,
RoomTypeId int, 
price int, 
minimumNights int, 
NumberOfReviews int, 
LastReview date, 
ReviewsPerMonth decimal, 
CalculatedHostListingsCount int, 
availability365 int, 
NumberOfReviewsLtm int, 
Licens string
) USING DELTA;
-- Out:
-- StatementMeta(, 58e82e3c-a4dd-46b4-9ed5-58dfda7a84c5, 3, Finished, Available)
-- <Spark SQL result set with 0 rows and 0 fields>
